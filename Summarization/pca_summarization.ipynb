# %% [markdown]
# # **Understanding natural language opinions**
# ## **with PCA and Topic Modeling techniques.**
#
# ### Objetivos:
#
#     Evaluar el pipeline agregando PCA.
#     Mejor modelo: KMeans con PCA

# %% [markdown]
# Comparacion KMeans sin y con PCA
# 12: mejor
# no identificado
# persp sociales
# centro
# liberalismo + control del estado
#
# no identificado
# control del estado
# centro
# NO me identifico + Decadencia politica
# Peronismo + persp social
#
# 13: mejor
# no identificado
# izquierda
# izquierda + razones sociales
# derecha
#
# no identificado
# izquierda
# izquierda + razones sociales
# derecha
#
# 14: mejor
# no tengo
# cfk
# otros + razones
# otros
#
# no tengo
# otros + razones
# cfk
# otros
# Favaloro
#
# 15: mejor
# de acuerdo
# ayuda no debe ser solo economica
# estado debe garantizar
# garantizar trabajo
# de acuerdo + plan
#
# de acuerdo
# estado debe garantizar y su rol
# en contra
# de acuerdo pero con ajustes
#
# 16: mejor
# acuerdo/desacuerdo
# falta info
# control
# no deberian ir directo a empresas
# rol empresas
#
# acuerdo/desacuerdo
# falta info
# control
# no deberian ir directo a empresas
# subsidio trabajador
#
# 17: peor
# lugares fisicos
# herramientas, seminarios, cursos, talleres
# excursiones
# mejores horarios
# menu
#
# cursos, herramientas, charlas,
# excursiones
# mejores horarios
# menu
#
# 18: peor
# horarios inconvenientes
# carga horaria
# ciclo fundamentos
# baches
# materias
#
# horarios inconvenientes
# carga horaria
# ciclo fundamentos
# rendir
# materias

# %% [markdown]
# Comparacion HDBSCAN con y sin PCA
# 12: igual
# izq
# anarquismo
# no cree sea respondible
# no identificado
#
# izq
# anarquismo
# no cree sea respondible
# no identificado
#
#
# 13: igual
# izq
# derecha
# mala exp en Arg
# izq por derechos
# izq por dis riqueza
#
# izq
# derecha
# mala exp en Arg
# izq por derechos
# izq por dis riqueza
#
# 14: igual
# no tengo
# fava
# alfonsin
# fava + deportistas
# cfk + norita cañas
#
# no tengo
# fava
# alfonsin
# fava + deportistas
# cfk + norita cañas
#
# 15: igual
# de acuerdo
# respons del estado
#
# de acuerdo
# respons del estado
#
#
# 16: igual
# de acuerdo
# desacuerdo
# falta info
# interesante
#
# de acuerdo
# desacuerdo
# falta info
# interesante
#
#
# 17: igual
# excursiones
# menu
# cursos de diseño
# mejores horarios
# menos carga
# mas tiempo libre
# lugares fisicos + materias
#
# excursiones
# menu
# cursos de diseño
# mejores horarios
# menos carga
# mas tiempo libre
# lugares fisicos + materias
#
#
# 18: igual
# horarios
# horario almuerzo
# carga horaria
# horarios cursada
# ciclo fundamentos
# horarios esparcidos
# materias
# materias + parciales
#
# horarios
# horario almuerzo
# carga horaria
# horarios cursada
# ciclo fundamentos
# horarios esparcidos
# materias
# materias + parciales

# %%
model1 = SentenceTransformer('hiiamsid/sentence_similarity_spanish_es')
model2 = TruncatedSVD(n_components=300)

# %%
documents = df[df['desafio']=='12']['texto'].values.tolist()
documents
# Out:
# ['No tengo una posición muy formada, pero me identifico con el liberalismo. Completamente liberal en lo social, y relativamente en lo económico. ',
#  'Nacionalista y popular. Porque considero que la economía se debe manejar en función de los intereses de las mayorías, las clases populares y los intereses nacionales, en defensa de la patria y sus recursos, y defender un mercado interno fuerte con buenos salarios ',
#  'Creo que las narrativas en términos politicos y económicos actuales no están a la altura del mundo actual. Son ideologías viejas surgidas en contextos totalmente diferentes, no responden a las necesidades del mundo actual, sus problemáticas y sus avances. Estamos viviendo el inicio de la cuarta revolución industrial y tenemos herramientas sociales de la era de los motores a vapor. Pero respondiendo a la consigna; creo que en términos económicos me siento mas identificado con el libre flujo de capitales y con control activo de un BUEN estado. ',
#  'El Estado regule, equitativo',
#  'De centro izquierda. O, digamos, una izquierda moderada. ',
#  'Me considero una persona de izquierda porque apoyo sus políticas ',
#  'Socialismo, partidos de izquierda... aunque muchas veces las acciones y decisiones de estos sectores no me representan porque actúan en base a intereses personales.. Hoy el sector que más representa mis intereses es el peronismo/kirchnerismo. ',
#  'Me defino como kirchnerista. Soberania política, independencia económica y justocia social.',
#  'Muy a favor de las ideas que mejoren la situación de la gente q tiene menos ingresos y  oportunidades',
#  'Centro izquierda, creo en la presencia de un Estado fuerte, en los DDHH, en una sociedad inclusiva,  crítica de la sociedad capitslista.creo en el bien común y en lampolítica como herramienta de transformación.',
#  'Creo que el sistema político económico esta en decadencia se deben buscar nuevas formas de organizacion',
#  'Considero que el estado debe intervenir orientando el desarrollo en función de las necesidades de la población, garantizándolos como derechos.',
#  'Supongo que me representa algo así como la centro izquierda porque, como ya mencioné en la primera pregunta, se acerca más a mi forma de pensar la sociedad, o sea, con ampliación de derechos y mayor igualdad. ',
#  'Me definiría como liberal. El estado no tiene por que intervenir en el mercado, por lo que hemos vivido hasta ahora en este país, queda demostrado.',
#  'No me siento identificada con ningún partido político.En materia económica simpatizo con las ideas liberales.',
#  'Hoy en dia no me siento interesada en el tema ni en debatir al respecto. Siento que no tenemos control alguno sobre la politica o la economia, sentarse a debatir con una persona sobre esto u opinar o charlar al respecto, enojarse, indignarse o hacerse mala sangre es totalmente inutil. No tenemos ningun control sobre lo que pasa en el pais, el unico momento es cada 4 años donde simplemente votamos a quien creemos que capaz podria representar nuestros ideales pero no lo hacen ni cerca. Sin embargo, no estoy para nada de acuerdo con el gobierno actual, ni el modo en como se plantea la idea de los ricos y los pobres, ni el resentimiento que se genera ni absolutamente nada. Respecto a los partidos de derecha, tampoco me siento de acuerdo con ellos pero siempre es como lo "menos peor" porque ya sabemos que con el tipo de gobiernos que son como el actual las cosas van en picada. Y cuando asuma otro gobierno las cosas tambien van a andar mal pero bueno',
#  'No puedo definirme ideológicamente en estos términos porque desconozco a qué hace referencia ',
#  'Me definirá de centro derecha pero realmente no soy de estar de acuerdo con los extremos aunque si me defino en general como de derecha. Estoy a favor de la mayor parte de los ideales que la misma presenta pero al mismo tiempo hay ciertos sectores de la derecha que no me gustan para nada. ',
#  'Ideología Centro Derecha',
#  'Desconozco',
#  'Me cuesta definirme, si tuviera que forzarme a hacerlo, diría que liberal en casi todas las aristas, pero en lo económico haría una salvedad y considero apropiada la intervención del estado en no dejar “caer” en la miseria a los sectores más desfavorecidos ',
#  'Suiza. Neutro.',
#  'No estoy interesado en la politica',
#  'No logro identificarme totalmente con ningún partido político, lo cual hace que no participe activamente de política más que cuando hay que votar. Siento que simpatizo más con ideas políticas de centro-izquierda, que ponen el foco en la población más vulnerable y pretenden apoyarla en sus reclamos, pero también soy consciente de que los partidos políticos de izquierda en Argentina presentan propuestas irreales y no tienen un gran peso político. Para definirme ideológicamente, me es más fácil expresar las ideas con las que no estoy de acuerdo, que serían políticas libertarias.',
#  'Ni idea. Quiero que todxs vivamos bien y que nadie joda a nadie. ',
#  'No lo haría, no me definiría. Si en otras cuestiones, pero en lo que se refiere a política y economía por lo menos en mi país no ',
#  'liberal, porque creo que el sistema que priorice las libertades individuales tiene mejor funcionamiento que cualquier otro que las cohiba',
#  'Centro - liberal',
#  'Políticamente pobre y económicamente pobre. ',
#  'Ser humano surfeando en delirios cósmicos ',
#  'Clase media, trabajador. Porque vivo trabajando para mantenerme a mi y a mi familia.',
#  'Considero que, la cultura argentina en tanto a lo político-económico es demasiado compleja. Y excede mi cosmovisión personal. Creo en los derechos humanos, y en la asistencia a las poblaciones que necesitan de terceros para garantizar sus derechos.Y que en nuestro país por sobre un debate del cómo en sus decisiones político- económicas, debe realizarse un cambio cultural. ',
#  'Peronista. No hubo otros gobiernos que generen la movilidad ascendente  que produjeron los gobiernos peronistas..',
#  'Estructuralista LATAM. Izquierda',
#  'De izquierda',
#  'Nacionalista republicano',
#  'Centro-derecha.',
#  'Probablemente no podría. Entiendo que lo más cercano sería decir que valoro el desarrollo de capacidades en el estado que permitan generar políticas públicas de calidad para mejorar la situación del país y sus habitantes. Asimismo, creo que el intercambio de ideas es una de las cosas que nos hace reflexionar para poder avanzar.',
#  'Como alguien que en el fondo es de izquierda, pero, para llegar a dnd queremos hay que sacrificar comodidad. El sistema que funciona es la derecha hoy en dia, mueve la economia y la gente vive mejor. Solo hay que saber un poco de historia y leer las noticias de afuera para darse cuenta. Es lo mejor de lo peor, pero si les molesta eso, entonces trabajen y ideen un nuevo sistema en vez de quejarse.',
#  '.....',
#  'Un poco de socialista utópico u anarquista',
#  'Pragmático: equilibrar el déficit fiscal, fomentar el trabajo y la mentalidad emprendedora, facilitar crédito y exención impositivaal que genera trabajo y empleo, hacer que dolar y peso convivan como monedas de curso legal (cómo en Uruguay)  promover el mérito y el talento y sostener con planesoaquienes lo necesitwn ',
#  'Socialista',
#  'No conozco mucho de ideologías políticas ni económicas. Pero creo que los políticos que nos representen deberían ser ejemplos de conducta y austeridad. Es inadmisible que quien ejerce en un cargo público no cumpla la ley y tenga una remuneración muy superior a la media.',
#  'No tengo una opinion formada aún',
#  'Anarcoperonista Lo de anarco .. por que me cuesta alinearme el el verticalismo representativo de las organizaciones politicas El modelo peronista se asemeja mas a la cultura latinoamericana ( la definicion de izq-der rsponden mas a la soc europea )',
#  'Simple proletariado que necesita trabajar para no quedar fuera del sistema perverso que tenemos que rendirle cuentas siempre. ',
#  'Me considero ideológicamente de izquierda porque estoy en contra del actual injusto reparto de la riqueza. En el orden local, nacional,regional y mundial. Y porque entiendo que el gran problema del mundo es el exceso de consumo en pequeñas franjas de las sociedades.',
#  'No tengo ni puta idea que es un termino politico economico',
#  'Que dificil, seria de izquierda, por las razones ya planteadas, justicia social, estado presente, economicamente no tengo mucho para decir. ',
#  'Nueva izquierda independiente. Porque mantenemos muchas de las banderas históricas de la "izquierda tradicional" pero alejada de los partidos burocráticos y las practicas personalistas. ',
#  'La economía es algo que me excede, siento que que haya tanta gente con mucha formación muy convencida del camino que hay que tomar -y que opinan cosas muy diferentes- indica que en realidad nadie tiene "la posta".Lo único de lo que estoy más o menos convencido es que el Estado puede y debe intervenir en la economía en algunas circunstancias (idealmente lo menos posible).',
#  'No adhiero a una ideología, pero mi tendencia política es hacia la izquierda. ',
#  'Sin partido político y argentina.',
#  'Estatista Intervencionista Socialista ¿Cómo lo Haría? expropiando latifundios y propiedades en manos extranjeras, interfiriendo  en el margen de ganancia de las empresas, modificando el sistema impositivo, quitando el iva, no pagaría la deuda externa, creando empresas nacionales, legislando el trabajo como un derecho y como una obligación , etc',
#  'De centro.',
#  'Soy peronista y k. Peronista x historia familiar, del pais y xq estoy convencida que el camino es x medio de la justicia social, los derechos laborales, la regulación del estado de y la distribución de la riqueza donde los mayores privilegiados sean los niños que sin el futuro del país. Y k xq soy contemporáneo y estoy convencida que hicieron  bien al país y siguieran las doctrinas peronistas',
#  'No creo que haya una ideologia politica que resuelva las distintas problematicas a perpetuidad. Por eso no tengo un pensamiento politico totalmente definido. En la actualidad me parece que los partidos de izquierda son los que mas me representan, mas alla que hay muchisimas cosas en las que podrian mejorar',
#  'Peronista, por qué estoy a favor de la defensa del vulnerable y los intereses nacionales.',
#  'Apolitico',
#  'Izquierda libertaria, anarquismo de izq, anarcosindicalismo, ciudadanía auto organizada con sindicatos u organizaciones similares, pero pragmáticas: eventualmente aliadas a un poder o instituciones estatales que busquen los mismos objetivos de emancipación de los (no) trabajadores mas perjudicados del sistema.',
#  'Soy peronista porque entiendo que es el único movimiento que apostó y logró la felicidad del pueblo en diferentes momentos de la historia de una manera transformadora ',
#  'Libertad y control con reglas estables',
#  'No tengo una ideología política económica definida',
#  'Centro izquierda, con ideas de sustentabilidad. Pero es dificil identificarse con la izquierda argentina. ',
#  'Me parece que este tema puede llegar a generar mucha polémica y controversias en la comunidad.',
#  'Creo que esta consigna precisa de un análisis mucho más profundo del que se puede abarcar en una respuesta simplificada como la que se propone aquí.']

# %%
emb_docs1 = model1.encode(documents)

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)
lsa_matrix = model2.fit_transform(X)
normalizer = Normalizer(copy=False)
emb_docs2 = normalizer.fit_transform(lsa_matrix)

# %%
emb_docs1.shape, emb_docs2.shape
# Out:
# ((67, 768), (67, 67))

# %%
result = np.concatenate((emb_docs1, emb_docs2), axis=1)

# %%
result.shape
# Out:
# (67, 835)

# %% [markdown]
# ## Preprocess

# %%
path_to_MyModule = '..'

import sys
sys.path.insert(0, path_to_MyModule) 

import pandas as pd
import matplotlib.pyplot as plt
from time import sleep

from MyModule.GeneralFunctions import *
from MyModule.SummarizationFunctions import *
from MyModule.SummarizationFunctions import MostRepresentativeDocs
from MyModule.SamplingFunctions import *
from MyModule.SemanticSimilarityFunctions import *
from MyModule.TopicModelingFunctinos import *

# %%
df = pd.read_excel('..\datos.xlsx')[['ID','texto','desafio']]

# %%
# Limpieza
df.drop_duplicates(subset='texto', inplace=True)

# Quitando texto de mas en columna "desafio"
df['desafio'] = df['desafio'].apply(lambda x: re.findall('[0-9]+', x)[0])

# A str
df['texto'] = df['texto'].astype(str)

# %%
# Helpers

import textwrap
def print_list(elements):
    "Make results fit the output"
    for element in elements:
        wrapped = []
        for item in element:
            wrapped.extend(textwrap.wrap(str(item), width=150))
        for line in wrapped:
            print(line)
        print()

# %% [markdown]
# ## Select a desafio and n_clusters

# %%
data = df[df['desafio']=='12']['texto'].values

n_clusters = 6
n_pca = 120

# %% [markdown]
# ## Select the most representative documents of each desafio's cluster
#
# 1. Obtener un vector semántico para cada documento (utilizando SentenceTransformers)
# 2. Clusterizar los documentos en base a sus vectores (utilizando KMeans o HDBScan)
# 3. Evaluar la similitud coseno de cada documento con el centroide de su cluster
# 4. Devolver los documentos ordenados de mayor a menos similitud
#
# Así, los documentos son presentados en el orden en el que más capturan el significado y las ideas expresadas por la mayoria.

# %%
pp_object = Preprocess(lemma=False, stopwords=False)
mrd = MostRepresentativeDocs(cluster_algorithm='kmeans', n_pca=n_pca)

# %%
mrd.elbow_pca_explained_variance(data)
# Out:
# Reducing embedding dimensions to 67

# %%
# all_res = {}
# for des in df['desafio'].unique():
#     this_data = df[df['desafio']==des]['texto'].values.tolist()
#     result = mrd.get_representatives(this_data, 5, pp_object)
#     all_res[des] = result

# %%
result = mrd.get_representatives(data, n_clusters=n_clusters, pp_object=None)
# Out:
# Reducing embedding dimensions to 67

# %%
mrd.get_average_silhouette_score()
# Out:
# 0.08539382

# %%
print_list(result[0])
# Out:
# No tengo ni puta idea que es un termino politico economico
# 0.73139596
#
# No creo que haya una ideologia politica que resuelva las distintas problematicas a perpetuidad. Por eso no tengo un pensamiento politico totalmente
# definido. En la actualidad me parece que los partidos de izquierda son los que mas me representan, mas alla que hay muchisimas cosas en las que
# podrian mejorar
# 0.6384937
#
# No estoy interesado en la politica
# 0.6213699
#
# No tengo una opinion formada aún
# 0.6160089
#
# No tengo una ideología política económica definida
# 0.59794277
#
# No puedo definirme ideológicamente en estos términos porque desconozco a qué hace referencia
# 0.5180751
#
# Hoy en dia no me siento interesada en el tema ni en debatir al respecto. Siento que no tenemos control alguno sobre la politica o la economia,
# sentarse a debatir con una persona sobre esto u opinar o charlar al respecto, enojarse, indignarse o hacerse mala sangre es totalmente inutil. No
# tenemos ningun control sobre lo que pasa en el pais, el unico momento es cada 4 años donde simplemente votamos a quien creemos que capaz podria
# representar nuestros ideales pero no lo hacen ni cerca. Sin embargo, no estoy para nada de acuerdo con el gobierno actual, ni el modo en como se
# plantea la idea de los ricos y los pobres, ni el resentimiento que se genera ni absolutamente nada. Respecto a los partidos de derecha, tampoco me
# siento de acuerdo con ellos pero siempre es como lo "menos peor" porque ya sabemos que con el tipo de gobiernos que son como el actual las cosas van
# en picada. Y cuando asuma otro gobierno las cosas tambien van a andar mal pero bueno
# 0.48673746
#
# Que dificil, seria de izquierda, por las razones ya planteadas, justicia social, estado presente, economicamente no tengo mucho para decir.
# 0.43360952

# %%
mrd.get_cluster_silhouette_score(4)
# Out:
# 0.11967466

# %% [markdown]
# ## Find clusters in cluster

# %%
mrd_cluster = MostRepresentativeDocs(cluster_algorithm='kmeans', n_pca=n_pca)
only_text = [v[0] for v in result[8]]
result_cluster = mrd_cluster.get_representatives(only_text, n_clusters=5, pp_object=None)
data = only_text.copy()
# Out:
# Reducing embedding dimensions to 19

# %%
mrd_cluster.get_cluster_silhouette_score(3)
# Out:
# 0.16317864

# %%
print_list(result_cluster[2])
# Out:
# Más sillitas para sentarse en el campus, más espacios con sombra natural, horarios de la combi más puntuales (desde la estación victoria siempre algún
# retraso tiene y eso hace que lleguemos tarde a clases)
# 0.6191901
#
# Una aplicación para sigedu y el campus virtual para no tener que entrar solo en la web, hablando todavia de sigedu siempre se traba y tiene mal
# conexión a la hora de la inscripción de las materias. Con la cuota que se paga creo que inversión no es un problema que falta en ese aspecto, faltan
# lugares de descansos ya que está re de moda baches eternos de 3 horas donde los que viven lejos no tienen como voler a casa y estar sentado todo ese
# tiempo es un plomazo. Aires condicionados en algunas aulas y biblioteca, faltarian más salas de estudio
# 0.57814884
#
# La cursada sea menor, es decir, entiendo que el nivel de exigencia de esta facultad es alto y estoy de acuerdo. Pero, noto una incongruencia con la
# exigencia externa a la cursada y la carga horaria. Se requiere mucho estudio constante, lectura, entregas semanalmente y aun así uno suele cursar de
# 9:00-18:00. Creo que si la hora de cursada fuese menor, se podría hasta rendir de manera mas óptima porque se le podría dedicar mas tiempo al
# estudio.Además, sugeriría que a la hora de corregir parcial final, noto que cuando los ejercicios son dividíos entre profesores (lo cual es lógico
# para poder terminar de corregir en un menor periodo de tiempo), suelen haber confusiones entre como evaluar y los puntajes que se otorgan por cada
# ejercicio. básicamente, noto que cuando los ejercicios son divididos, los criterios de corrección de cada uno son diferentes y eso confunde.
# 0.5634634
#
# un mejor acompañamiento para los que dejan Dormis. Actualmente no hay una lista actualizada ni completa de lugares para residir durante los años de
# universidad en los que no se contemplan plazas en las residencias tanto de Dormitorios como Jacaranda (tercero en adelante). Se podría crear un
# programa con una base de datos con los lugares mas contemplados de la universidad y con actualizaciones de lugares que consiguieron los alumnos, o
# incluso de quienes se reciben y saben que abandonan su lugar de residencia.
# 0.47954312
#
# MEJORES HORARIOS, arrancar temprano y terminar mas temprano. Que las tutoriales de matematica sean optativas, cada uni hace las guias cuando mejor le
# convenga. Dejenos administras nuestro propio tiempo de estudio. Mas arboles en el medio del campus, somos muchos alumnos y en verano no hay
# suficientes sombras.
# 0.39340642
#
# Un curso donde te enseñen a utilizar toda la maquinaria del laboratorio, dentro del mismo curso también estaría bueno que te enseñen algunos lugares
# donde conseguir materiales a la hora de tener que encarar un proyecto. Por ultimo que la clase de diseño técnico sea más profundizada.
# 0.17559493

# %% [markdown]
# # Comparacion KMeans con y sin PCA

# %%
data = df[df['desafio']=='13']['texto'].values

n_clusters = 5
n_pca = 100

# %%
pp_object = Preprocess(lemma=False, stopwords=False)
mrd_kmeans_pca = MostRepresentativeDocs(model_algo='both', cluster_algorithm='kmeans', n_pca=n_pca)

result_kmeans_pca = mrd_kmeans_pca.get_representatives(data, n_clusters=n_clusters, pp_object=pp_object)
# Out:
# Working with both model.
# Reducing embedding dimensions to 95

# %%
mrd_kmeans_pca.elbow_pca_explained_variance(data, pp_object=pp_object)
# Out:
# Working with both.
# Working with both model.
# Reducing embedding dimensions to 67

# %%
print_list(result_kmeans_pca[4])
# Out:
# Izquierda.Porque entiendo que las izquierdas luchan por una distribución de la riqueza más justa. Porque consideran que esa injusta distribución es el
# resultado de la acumulación y apropiación por parte de los sectores dominantes de la fuerza de trabajo de los sectores más pobres.Porque además fueron
# incorporando otras luchas como aquellas relacionadas a los derechos humanos, igualdad de géneros y la cuestión ambiental.
# 0.5299097260618679
#
# Me siento más identificada con partidos de izquierda porque tienen una visión que se acerca a la concepción de la política que tengo, o sea, a cómo
# pienso la sociedad. Esto está ligado a la igualdad, acceso a derechos esenciales para los sujetos: educación, salud, DDHH, etc.
# 0.502352964426275
#
# Me siento identificada socialmente con partidos de izquierda pero económicamente con partidos de centro. Nada de derecha. Pienso que tenemos que
# abogar por las libertades sociales pero a la vez económicamente no se puede librar todo a la suerte del mercado, así que creo que se necesita algún
# control
# 0.4649692555141438
#
# Izquierda. No comparto la totalidad de las propuestas de los partidos de izquierda, pero estoy más en desacuerdo con los partidos de derecha. Me
# parece que políticas liberales no contribuyen al crecimiento de un país en desarrollo, no estoy de acuerdo con la idea de que el enriquecimiento de
# una elite empresarial se "contagia" con el tiempo al resto de la población que no cuenta con los mismos recursos que tal minoría.
# 0.4646708058684164
#
# Descartó la izquierda en todas sus etapas. Valoro la libertad e igualdad , estuve en países comunistas y solo vi pobreza y tristeza. Creo en el
# esfuerzo, trabajo y dedicación pero por sobre todo en la Libertad
# 0.4528660634256286
#
# Ni con unos ni con otros, porque no han servido ni sirven las ultranzas para resolver los problemas de la gente, al menos en Argentina. Yo creo en
# gobiernos pragmáticos al servicio de toda la población (TODA), y si alguna vez apareciera en nuestro contexto esa posibilidad debería adoptar las
# mejores políticas y prácticas de gestión, integrando ideas de derecha, izquierda y centro.Creo además que la gestión resuelve problemas, y que el
# falso debate de posturas ideológicas empantana y paraliza, hace que la gente descrea de la política y de la democracia, porque empeoran su calidad de
# vida
# 0.4397815836588344
#
# Más identificado con izquierda. Lo tengo asociado a ampliar derechos a las minorías y a acciones tendientes a mejorar la realidad de los sectores más
# desfavorecidos.
# 0.42635522192583525
#
# Más identificada a partidos de izquierda. En general tienen más en cuenta las problemáticas sociales y defender derechos adquiridos. O derechos que se
# vulneran por el poder (empresarios e incluso el Estado).
# 0.4020402845509513
#
# Más de izquierda, por sus ideas y propuestas y conceptos en relación a la situación económica y social.
# 0.39595046551053775
#
# De izquierda. Porque me preocupa la calidad de vida de toda la población
# 0.38723427301457086
#
# Me siento identificado más con partidos de izquierda pq creo que son los que proponen o deberían proponer distribuir la riqueza entre la gente más
# pobre para que haya justicia social y los ricos no sean cada vez más ricos.
# 0.3837974739759327
#
# Mi opinión es de mucho desncanto, al ver lo que los partidos políticos le hacen al país. Sólo les interesa llegar al poder y mantenerse ahí.
# 0.3785193050009722
#
# Más de izquierda. Creo que en este mundo no todos tenemos las mismas oportunidades de inicio y las políticas de izquierda sirven para igualar esas
# oportunidades
# 0.3682650311612061
#
# Me siento identificado un poco más a partidos de izquierda, pero básicamente prefiero partidos de centro. Creo que las categorías izquierda-derecha,
# si bien representan algunos lineamientos generales de la población, tienden a tergiversar la interpretación de la realidad y generar falsas
# controversias que nos alejan de soluciones pragmáticas que promuevan mejoras en el bienestar colectivo.
# 0.3440540450838256
#
# Con los partidos de izquierda. Motivos: -cuestionamiento del statu quo -foco en el bienestar general más allá del individuo -politicas progresistas
# que buscan proteger a sectores desfavorecidos
# 0.3232657275817262
#
# Partidos de derecha. Creo q el camino para salir adelante es el trabajo, el esfuerzo y educación.
# 0.3110603759721602
#
# Con partidos de centro izquierda. La derecha limita derechos para las mayorías populares y si bien la izquierda no y tiene a ampliar al menos en
# Argentina no tiene vocación de poder por eso me identifico con la centro izquierda que amplía derechos a las mayorías y tiene vocación de poder
# 0.2978137236605734
#
# Podría decirse que mas de derecha. En general son por motivos económicos por sobre todo. Tambien pesa bastante la mala experiencia con partidos de
# "izquierda" en la Argentina, si bien coincido con varias premisas que plantean, la implementación y corrupción subyacente me han hecho reacio a
# identificarme con ellos.
# 0.28518605753645815
#
# Con el centro. Tiene que existir un equilibrio entre conciencia social y economía.
# 0.27813964216428805
#
# Izquierda. Calculo que gracias al pensamiento critico que me fomento la universidad.
# 0.26775237597781065
#
# Izquierda.  Honestamente no tengo idea de política, pero la mayoría de la gente que me gusta, con la que comparto valores (aplica para
# familiares/amiges/músicos/ artistas en general) son de izquierda.
# 0.2439290320062395
#
# Actualmente no me siento identificada con ninguno de los dos.Creo que todos los partidos políticos sólo piensan en en tener más poder, en su beneficio
# y no en el del pueblo.   Si realmente quisieran mejorar el bienestar de todos deberían buscar un consenso para gobernar mejor y con proyectos que
# beneficien a todos.
# 0.23396353153838104
#
# Socialmente, de centro-izquierda. Economicamente, de centro-derecha.
# 0.1932116567932999
#
# Izquierda Me indentifico más con la idea del beneficio popular y no individual, la redistribución de las riquezas
# 0.18901534490015987
#
# Izquierda. Al ser seres sociales y nuestra vida depender de otres no me cierran las posturas muy liberales o individualistas
# 0.1530444356267188
#
# Me siento idemtificado con los partidos de derecha. Así de facil: abajo la casta, arriba Milei
# 0.13663488985122915
#
# Izquierda Por tener conciencia  de clase, por influencia familiar, por que me gustan sus dirigentes políticos.
# 0.12542219821086834
#
# Me siento identificado con partidos de izquierda xq creo en la inclusión social, la solidaridad y empatia x el otro
# 0.11348035232361067
#
# De derecha, creo que todos teniendo capacidades debemos trabajar, estudiar, aprender un oficio, y ganar recursos dignos para vivir. La izquierda abusa
# de los planes eternos que no resuelven nada.
# 0.10968764668296471
#
# Con ninguno. Creo en los derechos universales humanos y comparto algunas ideas de diversas afiliaciones políticas.
# 0.10551705178825166
#
# Levemente más identificado con partidos de derecha. Los partidos de izquierda, al menos en el contexto de Argentina, no promueven propuestas
# realizables, constructivas y que puedan ser viables de ser llevadas a cabo, sino más bien idealizaciones sin ningún tipo de sustento.
# 0.05171501676946895

# %%
mrd_cluster = MostRepresentativeDocs(model_algo='both', cluster_algorithm='kmeans', n_pca=n_pca)
only_text = [v[0] for v in result_kmeans_pca[4]]
result_cluster = mrd_cluster.get_representatives(only_text, n_clusters=5, pp_object=pp_object)
data = only_text.copy()
# Out:
# Working with both model.
# Reducing embedding dimensions to 31

# %%
print_list(result_cluster[4])
# Out:
# Socialmente, de centro-izquierda. Economicamente, de centro-derecha.
# 0.7850345978692009
#
# Con el centro. Tiene que existir un equilibrio entre conciencia social y economía.
# 0.7444246114519609

# %%
pp_object = Preprocess(lemma=False, stopwords=False)
mrd_kmeans = MostRepresentativeDocs(model_algo='bert', cluster_algorithm='kmeans', n_pca=None)

result_kmeans = mrd_kmeans.get_representatives(data, n_clusters=n_clusters, pp_object=pp_object)
# Out:
# Working with SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# ).

# %%
print_list(result_kmeans[4])
# Out:
# ....
# 0.8264254
#
# Ninguna.
# 0.73329043
#
# Grabois
# 0.72019184
#
# No sé
# 0.65351963
#
# gallperin
# 0.48586822

# %%
mrd_cluster = MostRepresentativeDocs(model_algo='bert', cluster_algorithm='kmeans', n_pca=None)
only_text = [v[0] for v in result_kmeans[1]]
result_cluster = mrd_cluster.get_representatives(only_text, n_clusters=5, pp_object=pp_object)
data = only_text.copy()
# Out:
# Working with SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# ).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Summarization\pca_summarization.ipynb Cell 33 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Felipe/Desktop/Proyectos/NLP_Politica/Summarization/pca_summarization.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> mrd_cluster = MostRepresentativeDocs(model_algo='bert', cluster_algorithm='kmeans', n_pca=None)
#       <a href='vscode-notebook-cell:/c%3A/Users/Felipe/Desktop/Proyectos/NLP_Politica/Summarization/pca_summarization.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> only_text = [v[0] for v in result_kmeans[1]]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Felipe/Desktop/Proyectos/NLP_Politica/Summarization/pca_summarization.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> result_cluster = mrd_cluster.get_representatives(only_text, n_clusters=5, pp_object=None)
#       <a href='vscode-notebook-cell:/c%3A/Users/Felipe/Desktop/Proyectos/NLP_Politica/Summarization/pca_summarization.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a> data = only_text.copy()
#
# File c:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Summarization\..\MyModule\SummarizationFunctions.py:444, in MostRepresentativeDocs.get_representatives(self, documents, n_clusters, pp_object)
#     440 self.found_clusters = True
#     443 self.preprocess_and_encode()
# --> 444 self.fit_clustering_model()
#     445 self.label_docs_emb()
#     446 self.find_labels_means()
#
# File c:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Summarization\..\MyModule\SummarizationFunctions.py:187, in MostRepresentativeDocs.fit_clustering_model(self)
#     184 elif self.cluster_algorithm == 'hdbscan':
#     185       self.cluster_model = hdbscan.HDBSCAN(**self.kwargs)
# --> 187 self.cluster_model.fit(self.emb_docs)
#
# File c:\Users\Felipe\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1426, in KMeans.fit(self, X, y, sample_weight)
#    1415 self._validate_params()
#    1417 X = self._validate_data(
#    1418     X,
#    1419     accept_sparse="csr",
#    (...)
#    1423     accept_large_sparse=False,
#    1424 )
# -> 1426 self._check_params_vs_input(X)
#    1428 random_state = check_random_state(self.random_state)
#    1429 sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File c:\Users\Felipe\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1362, in KMeans._check_params_vs_input(self, X)
#    1361 def _check_params_vs_input(self, X):
# -> 1362     super()._check_params_vs_input(X, default_n_init=10)
#    1364     self._algorithm = self.algorithm
#    1365     if self._algorithm in ("auto", "full"):
#
# File c:\Users\Felipe\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:859, in _BaseKMeans._check_params_vs_input(self, X, default_n_init)
#     856 def _check_params_vs_input(self, X, default_n_init=None):
#     857     # n_clusters
#     858     if X.shape[0] < self.n_clusters:
# --> 859         raise ValueError(
#     860             f"n_samples={X.shape[0]} should be >= n_clusters={self.n_clusters}."
#     861         )
#     863     # tol
#     864     self._tol = _tolerance(X, self.tol)
#
# ValueError: n_samples=3 should be >= n_clusters=5.

# %%
print_list(result_cluster[4])
# Out:
# Creo que el sistema político económico esta en decadencia se deben buscar nuevas formas de organizacion
# 1.0000002

# %% [markdown]
# # Comparacion KMeans PCA con HDBSCAN PCA

# %%
data = df[df['desafio']=='12']['texto'].values

n_clusters = 6
n_pca = 100

# %%
pp_object = Preprocess(lemma=False, stopwords=False)
mrd_kmeans = MostRepresentativeDocs(cluster_algorithm='kmeans', n_pca=n_pca)

result_kmeans = mrd_kmeans.get_representatives(data, n_clusters=n_clusters, pp_object=None)
# Out:
# Reducing embedding dimensions to 67

# %%
print_list(result_kmeans[2])
# Out:
# Izquierda. Calculo que gracias al pensamiento critico que me fomento la universidad.
# 0.5005506
#
# Mi opinión es de mucho desncanto, al ver lo que los partidos políticos le hacen al país. Sólo les interesa llegar al poder y mantenerse ahí.
# 0.4648041
#
# De derecha, creo que todos teniendo capacidades debemos trabajar, estudiar, aprender un oficio, y ganar recursos dignos para vivir. La izquierda abusa
# de los planes eternos que no resuelven nada.
# 0.45210922
#
# Partidos de derecha. Creo q el camino para salir adelante es el trabajo, el esfuerzo y educación.
# 0.40438762
#
# Ni con unos ni con otros, porque no han servido ni sirven las ultranzas para resolver los problemas de la gente, al menos en Argentina. Yo creo en
# gobiernos pragmáticos al servicio de toda la población (TODA), y si alguna vez apareciera en nuestro contexto esa posibilidad debería adoptar las
# mejores políticas y prácticas de gestión, integrando ideas de derecha, izquierda y centro.Creo además que la gestión resuelve problemas, y que el
# falso debate de posturas ideológicas empantana y paraliza, hace que la gente descrea de la política y de la democracia, porque empeoran su calidad de
# vida
# 0.39690986
#
# A veces si, a veces no.
# 0.37905565
#
# Derecha %100, que se mueran los zurdos!
# 0.359931
#
# Con los de derecha. Por que promueven el empleo y la propiedad privada, el reconocimiento al esfuerzo y reconocen el mérito.
# 0.35734826
#
# Me siento idemtificado con los partidos de derecha. Así de facil: abajo la casta, arriba Milei
# 0.35049707
#
# Si hubiera que polarizar, diría izquierda. Pero Argentina acaba de perder, no tengo fuerzas para argumentar ni por qué CONICET debería mantenerme la
# beca.
# 0.3170572
#
# Actualmente no me siento identificada con ninguno de los dos.Creo que todos los partidos políticos sólo piensan en en tener más poder, en su beneficio
# y no en el del pueblo.   Si realmente quisieran mejorar el bienestar de todos deberían buscar un consenso para gobernar mejor y con proyectos que
# beneficien a todos.
# 0.30839676
#
# Con el centro. Tiene que existir un equilibrio entre conciencia social y economía.
# 0.30354446
#
# Me siento identificado con los partidos de derecha. La izquierda se basa en el resentimiento y el usufructo del esfuerzo de terceros, en igualar hacia
# abajo. No premia el esfuerzo.
# 0.2699489
#
# apartidario, descreo de los partidos
# 0.26474634
#
# De ninguno porque fui a otro planeta y vi otros modos de organización social.
# 0.25505665
#
# Descartó la izquierda en todas sus etapas. Valoro la libertad e igualdad , estuve en países comunistas y solo vi pobreza y tristeza. Creo en el
# esfuerzo, trabajo y dedicación pero por sobre todo en la Libertad
# 0.24383688
#
# Depende la dirigencia, hoy me identifico con partidos de izquierda, cuando gobierna mucho la derecha me gusta cambiar para equilibrar, y ya es hora
# 0.2321557
#
# De Izquierda pensando en igualar
# 0.2164284
#
# Izquierda Por tener conciencia  de clase, por influencia familiar, por que me gustan sus dirigentes políticos.
# 0.21581191
#
# De izquierda. Porque me preocupa la calidad de vida de toda la población
# 0.20330453
#
# No con ninguno. Son los dos de izquierda y ninguno genera cambios. Tambien me parece que politizar las clases es un problema. La educacion deberia
# siempre mostrar los dos lados y los profesores tienen que entender que somos otra generacion. Se me ocurren ejemplos de situaciones en clase que son
# medio molestos.
# 0.1969719
#
# Izquierda Me indentifico más con la idea del beneficio popular y no individual, la redistribución de las riquezas
# 0.1952511
#
# Podría decirse que mas de derecha. En general son por motivos económicos por sobre todo. Tambien pesa bastante la mala experiencia con partidos de
# "izquierda" en la Argentina, si bien coincido con varias premisas que plantean, la implementación y corrupción subyacente me han hecho reacio a
# identificarme con ellos.
# 0.17063476
#
# Izquierda. Al ser seres sociales y nuestra vida depender de otres no me cierran las posturas muy liberales o individualistas
# 0.1466607

# %%
mrd_cluster = MostRepresentativeDocs(cluster_algorithm='kmeans', n_pca=n_pca)
only_text = [v[0] for v in result_kmeans[2]]
result_cluster = mrd_cluster.get_representatives(only_text, n_clusters=5, pp_object=None)
data = only_text.copy()
# Out:
# Reducing embedding dimensions to 24

# %%
print_list(result_cluster[2])
# Out:
# Partidos de derecha. Creo q el camino para salir adelante es el trabajo, el esfuerzo y educación.
# 0.73213184
#
# Con los de derecha. Por que promueven el empleo y la propiedad privada, el reconocimiento al esfuerzo y reconocen el mérito.
# 0.54835504
#
# Izquierda. Calculo que gracias al pensamiento critico que me fomento la universidad.
# 0.5245135
#
# Descartó la izquierda en todas sus etapas. Valoro la libertad e igualdad , estuve en países comunistas y solo vi pobreza y tristeza. Creo en el
# esfuerzo, trabajo y dedicación pero por sobre todo en la Libertad
# 0.47398445
#
# De derecha, creo que todos teniendo capacidades debemos trabajar, estudiar, aprender un oficio, y ganar recursos dignos para vivir. La izquierda abusa
# de los planes eternos que no resuelven nada.
# 0.41982195

# %%
pp_object = Preprocess(lemma=False, stopwords=False)

my_dict = {
    'min_cluster_size': 4, # Small minimum cluster size
    'min_samples': 1, # Allow singletons to be considered clusters
    'cluster_selection_epsilon': 0.1,
    'cluster_selection_method': 'leaf', # Favor smaller clusters
    'algorithm': 'best', # Use the more precise algorithm
    'metric': 'euclidean', # Euclidean distance metric
    'core_dist_n_jobs': -1, # Use all available cores for core distance calculations
    'allow_single_cluster': True, # Allow a single cluster to be returned
    'prediction_data': True, # Use prediction data to refine cluster boundaries
    'leaf_size': 40 # Leaf size for tree building
}

mrd_hdb = MostRepresentativeDocs(cluster_algorithm='hdbscan', n_pca=n_pca, **my_dict)

result_hdb = mrd_hdb.get_representatives(data, n_clusters=n_clusters, pp_object=None)
# Out:
# Reducing embedding dimensions to 24

# %%
print_list(result_hdb[-1])
# Out:
# Podría decirse que mas de derecha. En general son por motivos económicos por sobre todo. Tambien pesa bastante la mala experiencia con partidos de
# "izquierda" en la Argentina, si bien coincido con varias premisas que plantean, la implementación y corrupción subyacente me han hecho reacio a
# identificarme con ellos.
# 0.26392663
#
# A veces si, a veces no.
# 0.24213386
#
# Con los de derecha. Por que promueven el empleo y la propiedad privada, el reconocimiento al esfuerzo y reconocen el mérito.
# 0.18574576
#
# Me siento identificado con los partidos de derecha. La izquierda se basa en el resentimiento y el usufructo del esfuerzo de terceros, en igualar hacia
# abajo. No premia el esfuerzo.
# 0.18321624
#
# Si hubiera que polarizar, diría izquierda. Pero Argentina acaba de perder, no tengo fuerzas para argumentar ni por qué CONICET debería mantenerme la
# beca.
# 0.15937833
#
# apartidario, descreo de los partidos
# 0.15775172
#
# Izquierda. Al ser seres sociales y nuestra vida depender de otres no me cierran las posturas muy liberales o individualistas
# 0.12877096
#
# Ni con unos ni con otros, porque no han servido ni sirven las ultranzas para resolver los problemas de la gente, al menos en Argentina. Yo creo en
# gobiernos pragmáticos al servicio de toda la población (TODA), y si alguna vez apareciera en nuestro contexto esa posibilidad debería adoptar las
# mejores políticas y prácticas de gestión, integrando ideas de derecha, izquierda y centro.Creo además que la gestión resuelve problemas, y que el
# falso debate de posturas ideológicas empantana y paraliza, hace que la gente descrea de la política y de la democracia, porque empeoran su calidad de
# vida
# 0.09621528
#
# Derecha %100, que se mueran los zurdos!
# 0.056998193
#
# Izquierda. Calculo que gracias al pensamiento critico que me fomento la universidad.
# 0.04785464
#
# Depende la dirigencia, hoy me identifico con partidos de izquierda, cuando gobierna mucho la derecha me gusta cambiar para equilibrar, y ya es hora
# 0.029915353
#
# Mi opinión es de mucho desncanto, al ver lo que los partidos políticos le hacen al país. Sólo les interesa llegar al poder y mantenerse ahí.
# -0.012115763
#
# No con ninguno. Son los dos de izquierda y ninguno genera cambios. Tambien me parece que politizar las clases es un problema. La educacion deberia
# siempre mostrar los dos lados y los profesores tienen que entender que somos otra generacion. Se me ocurren ejemplos de situaciones en clase que son
# medio molestos.
# -0.01945894
#
# De derecha, creo que todos teniendo capacidades debemos trabajar, estudiar, aprender un oficio, y ganar recursos dignos para vivir. La izquierda abusa
# de los planes eternos que no resuelven nada.
# -0.0319793
#
# Partidos de derecha. Creo q el camino para salir adelante es el trabajo, el esfuerzo y educación.
# -0.04548629
#
# Izquierda Me indentifico más con la idea del beneficio popular y no individual, la redistribución de las riquezas
# -0.06298143
#
# Descartó la izquierda en todas sus etapas. Valoro la libertad e igualdad , estuve en países comunistas y solo vi pobreza y tristeza. Creo en el
# esfuerzo, trabajo y dedicación pero por sobre todo en la Libertad
# -0.08806598
#
# De izquierda. Porque me preocupa la calidad de vida de toda la población
# -0.11662791
#
# Con el centro. Tiene que existir un equilibrio entre conciencia social y economía.
# -0.13587691
#
# Izquierda Por tener conciencia  de clase, por influencia familiar, por que me gustan sus dirigentes políticos.
# -0.1594563
#
# Me siento idemtificado con los partidos de derecha. Así de facil: abajo la casta, arriba Milei
# -0.18015021
#
# De Izquierda pensando en igualar
# -0.21144249
#
# Actualmente no me siento identificada con ninguno de los dos.Creo que todos los partidos políticos sólo piensan en en tener más poder, en su beneficio
# y no en el del pueblo.   Si realmente quisieran mejorar el bienestar de todos deberían buscar un consenso para gobernar mejor y con proyectos que
# beneficien a todos.
# -0.21707693
#
# De ninguno porque fui a otro planeta y vi otros modos de organización social.
# -0.2444207

# %%
mrd_cluster = MostRepresentativeDocs(cluster_algorithm='hdbscan', n_pca=n_pca, **my_dict)
only_text = [v[0] for v in result_hdb[-1]]
result_cluster = mrd_cluster.get_representatives(only_text, n_clusters=5, pp_object=None)
data = only_text.copy()
# Out:
# Reducing embedding dimensions to 24

# %%
print_list(result_cluster[-1])
# Out:
# Izquierda Por tener conciencia  de clase, por influencia familiar, por que me gustan sus dirigentes políticos.
# 0.29001978
#
# Me siento idemtificado con los partidos de derecha. Así de facil: abajo la casta, arriba Milei
# 0.18262899
#
# Me siento identificado con los partidos de derecha. La izquierda se basa en el resentimiento y el usufructo del esfuerzo de terceros, en igualar hacia
# abajo. No premia el esfuerzo.
# 0.1785295
#
# Mi opinión es de mucho desncanto, al ver lo que los partidos políticos le hacen al país. Sólo les interesa llegar al poder y mantenerse ahí.
# 0.16350508
#
# De ninguno porque fui a otro planeta y vi otros modos de organización social.
# 0.12410171
#
# No con ninguno. Son los dos de izquierda y ninguno genera cambios. Tambien me parece que politizar las clases es un problema. La educacion deberia
# siempre mostrar los dos lados y los profesores tienen que entender que somos otra generacion. Se me ocurren ejemplos de situaciones en clase que son
# medio molestos.
# 0.08772516
#
# Descartó la izquierda en todas sus etapas. Valoro la libertad e igualdad , estuve en países comunistas y solo vi pobreza y tristeza. Creo en el
# esfuerzo, trabajo y dedicación pero por sobre todo en la Libertad
# 0.07814271
#
# Actualmente no me siento identificada con ninguno de los dos.Creo que todos los partidos políticos sólo piensan en en tener más poder, en su beneficio
# y no en el del pueblo.   Si realmente quisieran mejorar el bienestar de todos deberían buscar un consenso para gobernar mejor y con proyectos que
# beneficien a todos.
# 0.054206133
#
# Con el centro. Tiene que existir un equilibrio entre conciencia social y economía.
# 0.022982702
#
# Derecha %100, que se mueran los zurdos!
# 0.017376713
#
# De derecha, creo que todos teniendo capacidades debemos trabajar, estudiar, aprender un oficio, y ganar recursos dignos para vivir. La izquierda abusa
# de los planes eternos que no resuelven nada.
# 0.014420125
#
# Si hubiera que polarizar, diría izquierda. Pero Argentina acaba de perder, no tengo fuerzas para argumentar ni por qué CONICET debería mantenerme la
# beca.
# -0.00037366198
#
# Ni con unos ni con otros, porque no han servido ni sirven las ultranzas para resolver los problemas de la gente, al menos en Argentina. Yo creo en
# gobiernos pragmáticos al servicio de toda la población (TODA), y si alguna vez apareciera en nuestro contexto esa posibilidad debería adoptar las
# mejores políticas y prácticas de gestión, integrando ideas de derecha, izquierda y centro.Creo además que la gestión resuelve problemas, y que el
# falso debate de posturas ideológicas empantana y paraliza, hace que la gente descrea de la política y de la democracia, porque empeoran su calidad de
# vida
# -0.00550885
#
# Izquierda. Calculo que gracias al pensamiento critico que me fomento la universidad.
# -0.019261409
#
# A veces si, a veces no.
# -0.022176297
#
# Izquierda. Al ser seres sociales y nuestra vida depender de otres no me cierran las posturas muy liberales o individualistas
# -0.025820993
#
# Podría decirse que mas de derecha. En general son por motivos económicos por sobre todo. Tambien pesa bastante la mala experiencia con partidos de
# "izquierda" en la Argentina, si bien coincido con varias premisas que plantean, la implementación y corrupción subyacente me han hecho reacio a
# identificarme con ellos.
# -0.04761235
#
# Izquierda Me indentifico más con la idea del beneficio popular y no individual, la redistribución de las riquezas
# -0.047836445
#
# Con los de derecha. Por que promueven el empleo y la propiedad privada, el reconocimiento al esfuerzo y reconocen el mérito.
# -0.075214565
#
# De Izquierda pensando en igualar
# -0.12269397
#
# Depende la dirigencia, hoy me identifico con partidos de izquierda, cuando gobierna mucho la derecha me gusta cambiar para equilibrar, y ya es hora
# -0.15595
#
# Partidos de derecha. Creo q el camino para salir adelante es el trabajo, el esfuerzo y educación.
# -0.17131646
#
# apartidario, descreo de los partidos
# -0.17135039
#
# De izquierda. Porque me preocupa la calidad de vida de toda la población
# -0.19108872

# %% [markdown]
# ## Word count plot
#
# Plotear las palabras mas frecuentes para cada cluster

# %%
pp_object_transformers = Preprocess(lemma=False, stopwords=False, alphanumeric=False, join=False)
pp_object_word_count = Preprocess(lemma=False)

mrd.plot_word_counts(data, n_clusters=n_clusters, pp_object_transformers=pp_object_transformers, pp_object_word_count=pp_object_word_count)
# mrd_cluster.plot_word_counts(data, n_clusters=n_clusters, pp_object_transformers=pp_object_transformers, pp_object_word_count=pp_object_word_count)

# %% [markdown]
# ## Finding optimum K
# Eje X: numero de clusters
#
# Eje Y: Sum of Squared Distance de cada punto con su centroide

# %%
mrd.elbow_method(data, k_range=[1, 20], pp_object=pp_object)

# %%
mrd.plot_elbow_silhouette_score(range_n_clusters=[2,20])

# %% [markdown]
# ## Clusters: Size and Shape
#
# ATENCION:
#
# debido a que primero se realiza una reduccion de dimensiones, el tamaño y la forma de cada cluster del gráfico puede ser distinto al encontrado en la realidad.

# %%
mrd.visualize_documents_kmeans(data, n_clusters=n_clusters, pp_object=pp_object)

# %% [markdown]
# # Combination: summarization for each topic's cluster

# %% [markdown]
# Apply T5 and BETO summarization to each cluster

# %%
# Models
beto = BETOSummary()
t5 = T5Summary()
mrd = MostRepresentativeDocs()
# Out:
# ckpt:
# mrm8488/bert2bert_shared-spanish-finetuned-summarization
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']
# ckpt:
# josmunpen/mt5-small-spanish-summarization

# %%
desafio = '18'
data = df.query(f'desafio == "{desafio}"')['texto'].values
pp_object = Preprocess(lemma=False, stopwords=False, alphanumeric=False, join=False)

# %%
labeled_docs = mrd.cluster_and_label_original_docs(data, 5, pp_object)

for key, values in labeled_docs.items():
    values = pp_object.preprocess(values)
    text = '.\n'.join(values)
    print(f'BERT, Cluster {key}:\n{beto.generate_summary(text)}\n\n')
    sleep(2)
    print(f'T5, Cluster {key}:\n{t5.generate_summary(text)}\n\n')
# Out:
# BERT, Cluster 4:
# ['Los horarios de limpieza de los banos. La carga horaria, hay periodo en los que ni siquiera tengo tiempo de almorzar', 'Los horarios de limpieza de los banos. La carga horaria, hay días en los que ni siquiera tengo tiempo para almorzar y en general']
#
#
# T5, Cluster 4:
# ['la carga horaria y los horarios de limpieza de los banos', 'la carga horaria y los horarios de limpieza de los banos']
#
#
# BERT, Cluster 3:
# ['Las materias del ciclo de fundamentos no tienen que ver con mi carrera, los horarios, el cansansio y la exigencia sostenida durante el ano.', 'La falta de apoyo par varios de los alunos ( 4 horas de diferencia ) para adaptarse en los pmieros anos']
#
#
# T5, Cluster 3:
# ['la falta de apoyo a las materias del ciclo de fundamentos', 'la falta de apoyo a las materias del ciclo de fundamentos']
#
#
# BERT, Cluster 1:
# ['Las clases en dh tienen mucho potencial pero dejan mucho que desear', 'Las clases en dh tienen mucho potencial pero dejan mucho que desear']
#
#
# T5, Cluster 1:
# ['la poca seriedad que le ponen muchos de los estudiantes, una de las escuelas mas caras de argentina', 'la poca seriedad que le ponen muchos de los estudiantes, una de las escuelas mas caras de argentina']
#
#
# BERT, Cluster 2:
# ['La distancia de capital hasta el campus. El viaje a la universidad y los horarios de cursada...', 'La distancia de capital hasta el campus. El viaje a la universidad y los horarios de cursada...']
#
#
# T5, Cluster 2:
# ['los horarios de cursada', 'los horarios de cursada']
#
#
# BERT, Cluster 0:
# ['La carga horaria y minimizar los baches entre las clases horarias y minimizar el bache de las clases', 'La carga horaria y minimizar los baches entre las clases nocturnas y minimizar el bache de las clases']
#
#
# T5, Cluster 0:
# ['los baches minimizan los baches y minimizar los baches', 'los baches minimizan los baches y minimizar los baches']

# %% [markdown]
# # Sample representative docs

# %%
desafio = '17'

documents = df[df['desafio']==desafio]['texto'].values

pp_object = Preprocess(lemma=False, stopwords=False, alphanumeric=False, join=False)

sr = SampleRepresentatives()
res = sr.get_sample(documents, pp_object=pp_object, n_clusters=5)

# %%
print(f'Desafio: {desafio}')
for key, value in res.items():
    print(f'\nCluster: {key}\n')
    for v in value[:3]:
        print(v)
# Out:
# Desafio: 17
#
# Cluster: 1
#
# Menos tareas extracurriculares ya que tenemos mucha carga horaria de cursada
# mantas en la biblioteca.
# Mejores horarios de cursada (menos baches).
#
# Cluster: 3
#
# Horarios mas normales
# Horarios más estructurados, que sean o en la mañana o en la tarde, que estén juntos, y que estén distribuidos de forma uniforme a lo largo de la semana.
# más horarios de combis.
#
# Cluster: 0
#
# Comida sin harina en el kiosco
# Mesa de ping pong, canchita de futbol tenis y mesa teqball (es la mesa tipo ping pong para jugar con pelota de futbol)
# más comidas hechas como tartas, ensaladas, etc
#
# Cluster: 2
#
# Estaria bueno que la experiencia 2023 tuviese clases magatrales mas pequeñas, de todas maneras me encanto como se dicto esta materia
# Más sillitas para sentarse en el campus, más espacios con sombra natural, horarios de la combi más puntuales (desde la estación victoria siempre algún retraso tiene y eso hace que lleguemos tarde a clases)
# La cursada sea menor, es decir, entiendo que el nivel de exigencia de esta facultad es alto y estoy de acuerdo. Pero, noto una incongruencia con la exigencia externa a la cursada y la carga horaria. Se requiere mucho estudio constante, lectura, entregas semanalmente y aun así uno suele cursar de 9:00-18:00. Creo que si la hora de cursada fuese menor, se podría hasta rendir de manera mas óptima porque se le podría dedicar mas tiempo al estudio.Además, sugeriría que a la hora de corregir parcial final, noto que cuando los ejercicios son dividíos entre profesores (lo cual es lógico para poder terminar de corregir en un menor periodo de tiempo), suelen haber confusiones entre como evaluar y los puntajes que se otorgan por cada ejercicio. básicamente, noto que cuando los ejercicios son divididos, los criterios de corrección de cada uno son diferentes y eso confunde.
#
# Cluster: 4
#
# Mas salidas o expediciones
# excursiones
# Excursiones
