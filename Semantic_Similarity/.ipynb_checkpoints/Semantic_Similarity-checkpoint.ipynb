# %%
import pandas as pd
import regex as re
import unidecode
import nltk
import spacy
import time

path_to_MyModule = '..'

import sys
sys.path.insert(0, path_to_MyModule) 

from MyModule.NLPFunctions import *

# %%
df = pd.read_excel('datos.xlsx')[['ID','texto','desafio']]

# %%
# Limpieza
df.drop_duplicates(subset='texto', inplace=True)

# Quitando texto de mas en columna "desafio"
df['desafio'] = df['desafio'].apply(lambda x: re.findall('[0-9]+', x)[0])

# A str
df['texto'] = df['texto'].astype(str)

# %% [markdown]
# # TF-IDF

# %%
pp = Preprocess()

model = TF_IDF_Model(df, pp)
matrix = model.train('texto')

model.predict_old('Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.')

print('\n')

model.predict_new('apoyar a messi')
# Out:
# Comparing:
# ['Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.']
#
# ----
# 0.
# Me siento mas identificado con los partidos de derecha. Mi principal motivo es que en mi país, Argentina, los partidos de izquierda están asociados a mucha corrupción.
# Score: 0.2524335281664663
# ----
# 1.
# Me siento más identificado con los partidos de izquierda porque son los que luchan contra la desigualdad y no la ven como algo natural, como sí lo hace la derecha
# Score: 0.2085362617250446
# ----
# 2.
# derecha
# Score: 0.19562404732810829
# ----
# 3.
# De izquierda, la derecha nunca estuvo a favor del trabajador.
# Score: 0.16077758266031264
# ----
# 4.
# Ideología Centro Derecha
# Score: 0.15108397378759436
# ----
# 5.
# Derecha. No soy partidario de ningún político pero si tengo que decir que se acerca más a mi ideología diría que la derecha es más acertada
# Score: 0.1333349191762562
# ----
# 6.
# De izquierda
# Score: 0.12368000375121829
# ----
# 7.
# Centro-derecha.
# Score: 0.12315304754504355
# ----
# 8.
# Socialmente, de centro-izquierda. Economicamente, de centro-derecha.
# Score: 0.11823117821065426
# ----
# 9.
# Un poco más con los de izquierda. No me gustan los partidos de derecha.
# Score: 0.11340159341456241
#
#
# Comparing:
# apoyar a messi
#
# ----
# 0.
# Messi
# Score: 0.6899105804031194
# ----
# 1.
# Messi, actualmente no hay ningún otro referente que valga la pena apoyar/reconocer, uno mas inútil que el otro
# Score: 0.48403018108926193
# ----
# 2.
# Messi, es un ejemplo de esfuerzo y superación, una figura a seguir y un ídolo. Una persona que triunfó haciendo lo que más le gusta.
# Score: 0.2207832573766238
# ----
# 3.
# No logro identificarme totalmente con ningún partido político, lo cual hace que no participe activamente de política más que cuando hay que votar. Siento que simpatizo más con ideas políticas de centro-izquierda, que ponen el foco en la población más vulnerable y pretenden apoyarla en sus reclamos, pero también soy consciente de que los partidos políticos de izquierda en Argentina presentan propuestas irreales y no tienen un gran peso político. Para definirme ideológicamente, me es más fácil expresar las ideas con las que no estoy de acuerdo, que serían políticas libertarias.
# Score: 0.11404786945560308
# ----
# 4.
# Ser humano surfeando en delirios cósmicos
# Score: 0.0
# ----
# 5.
# Desconozco la situación en detalle como para tirar fruta
# Score: 0.0
# ----
# 6.
# No se que comentar acá.
# Score: 0.0
# ----
# 7.
# Favaloro. Logró algo que no se había realizado nunca y murió ahogado por las deudas y un gobierno al que sólo le importaba cobrar sus deudas.
# Score: 0.0
# ----
# 8.
# Horarios más estructurados, que sean o en la mañana o en la tarde, que estén juntos, y que estén distribuidos de forma uniforme a lo largo de la semana.
# Score: 0.0
# ----
# 9.
# Clase media, trabajador. Porque vivo trabajando para mantenerme a mi y a mi familia.
# Score: 0.0
# C:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Semantic_Similarity\..\MyModule\NLPFunctions.py:366: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ID not in self.df['ID'].values:
# C:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Semantic_Similarity\..\MyModule\NLPFunctions.py:371: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   index_and_scores = self.df_similarity[ID].nlargest(N+1)[1:]
# {628: ['Messi', 0.6899105804031194],
#  610: ['Messi, actualmente no hay ningún otro referente que valga la pena apoyar/reconocer, uno mas inútil que el otro',
#   0.48403018108926193],
#  608: ['Messi, es un ejemplo de esfuerzo y superación, una figura a seguir y un ídolo. Una persona que triunfó haciendo lo que más le gusta.',
#   0.2207832573766238],
#  606: ['No logro identificarme totalmente con ningún partido político, lo cual hace que no participe activamente de política más que cuando hay que votar. Siento que simpatizo más con ideas políticas de centro-izquierda, que ponen el foco en la población más vulnerable y pretenden apoyarla en sus reclamos, pero también soy consciente de que los partidos políticos de izquierda en Argentina presentan propuestas irreales y no tienen un gran peso político. Para definirme ideológicamente, me es más fácil expresar las ideas con las que no estoy de acuerdo, que serían políticas libertarias.',
#   0.11404786945560308],
#  573: ['Ser humano surfeando en delirios cósmicos ', 0.0],
#  572: ['Desconozco la situación en detalle como para tirar fruta', 0.0],
#  571: ['No se que comentar acá. ', 0.0],
#  570: ['Favaloro. Logró algo que no se había realizado nunca y murió ahogado por las deudas y un gobierno al que sólo le importaba cobrar sus deudas.',
#   0.0],
#  560: ['Horarios más estructurados, que sean o en la mañana o en la tarde, que estén juntos, y que estén distribuidos de forma uniforme a lo largo de la semana. ',
#   0.0],
#  568: ['Clase media, trabajador. Porque vivo trabajando para mantenerme a mi y a mi familia.',
#   0.0]}

# %% [markdown]
# # LSA

# %%
pp_object = Preprocess()
model = LSA_Model(df, pp_object=pp_object)

model.train(n_components = 5)

model.predict_old(748)

print('\n')

model.predict_new('El Estado regule, equitativo')
# Out:
# Comparing:
# ['Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.']
#
# ----
# 0.
# Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.
# Score: 1.0
# ----
# 1.
# Partidos de derecha. Creo que históricamente los partidos considerados de izquierda no han cumplido con los ideales que supuestamente defienden. Sin embargo los de derecha se relacionan más con mi historia familiar y la defensa de esos derechos y el tipo de sociedad en la que deseo vivir.
# Score: 0.9975579995910803
# ----
# 2.
# Con las ideas que surgen de partidos de izquierda en tanto promueven el desarrollo del estado orientado a llevar adelante políticas sociales y económicas con objetivos y nociones de equidad y justicia social.
# Score: 0.9971095925377355
# ----
# 3.
# Depende la dirigencia, hoy me identifico con partidos de izquierda, cuando gobierna mucho la derecha me gusta cambiar para equilibrar, y ya es hora
# Score: 0.9959958567581562
# ----
# 4.
# Me siento identificado un poco más a partidos de izquierda, pero básicamente prefiero partidos de centro. Creo que las categorías izquierda-derecha, si bien representan algunos lineamientos generales de la población, tienden a tergiversar la interpretación de la realidad y generar falsas controversias que nos alejan de soluciones pragmáticas que promuevan mejoras en el bienestar colectivo.
# Score: 0.9958977986021028
# ----
# 5.
# Me siento más identificado con los partidos de izquierda porque son los que luchan contra la desigualdad y no la ven como algo natural, como sí lo hace la derecha
# Score: 0.9958108109074846
# ----
# 6.
# Me considero una persona de izquierda porque apoyo sus políticas
# Score: 0.994110088782506
# ----
# 7.
# Supongo que me representa algo así como la centro izquierda porque, como ya mencioné en la primera pregunta, se acerca más a mi forma de pensar la sociedad, o sea, con ampliación de derechos y mayor igualdad.
# Score: 0.9939221196656929
# ----
# 8.
# Me identifico con los partidos que se interesan por la justicia social.
# Score: 0.9917437489300673
# ----
# 9.
# Izquierda.Especialmente, sensibilidad social, igualdad, lucha por los derechos.
# Score: 0.9916987739570643
# Comparing:
# No tengo ni puta idea que es un termino politico
#
# ----
# 0.
# No tengo ni puta idea que es un termino politico economico
# Score: 0.9998278919770169
# ----
# 1.
# Que por momentos, en algunas áreas pidan encarar proyectos y no se de ningún tipo de acompañamiento y sea puro improvisación del alumno con lo que tenga a su alcance para presentar algo.
# Score: 0.9873615738209396
# ----
# 2.
# Concuerdo totalmente
# Score: 0.9820266682630936
# ----
# 3.
# Me definiría como liberal. El estado no tiene por que intervenir en el mercado, por lo que hemos vivido hasta ahora en este país, queda demostrado.
# Score: 0.9780966624194453
# ----
# 4.
# Nada nuevo
# Score: 0.9726802037899089
# ----
# 5.
# Nuevas sedes
# Score: 0.9723651651553652
# ----
# 6.
# Muy difícil de responder. Puedo pensar solo en referentes científicos y deportistas.
# Score: 0.9687215397575654
# ----
# 7.
# liberal, porque creo que el sistema que priorice las libertades individuales tiene mejor funcionamiento que cualquier otro que las cohiba
# Score: 0.96734782582575
# ----
# 8.
# No tengo admiración por nadie, pero lo que hace Santi Maratea me parece bueno.
# Score: 0.9616221589823739
# ----
# 9.
# Si hubiera que polarizar, diría izquierda. Pero Argentina acaba de perder, no tengo fuerzas para argumentar ni por qué CONICET debería mantenerme la beca.
# Score: 0.9589058180399495
# {300: ['No tengo ni puta idea que es un termino politico economico',
#   0.9998278919770169],
#  483: ['Que por momentos, en algunas áreas pidan encarar proyectos y no se de ningún tipo de acompañamiento y sea puro improvisación del alumno con lo que tenga a su alcance para presentar algo. ',
#   0.9873615738209396],
#  654: ['Concuerdo totalmente', 0.9820266682630936],
#  663: ['Me definiría como liberal. El estado no tiene por que intervenir en el mercado, por lo que hemos vivido hasta ahora en este país, queda demostrado.',
#   0.9780966624194453],
#  409: ['Nada nuevo', 0.9726802037899089],
#  469: ['Nuevas sedes', 0.9723651651553652],
#  747: ['Muy difícil de responder. Puedo pensar solo en referentes científicos y deportistas.',
#   0.9687215397575654],
#  587: ['liberal, porque creo que el sistema que priorice las libertades individuales tiene mejor funcionamiento que cualquier otro que las cohiba',
#   0.96734782582575],
#  644: ['No tengo admiración por nadie, pero lo que hace Santi Maratea me parece bueno. ',
#   0.9616221589823739],
#  595: ['Si hubiera que polarizar, diría izquierda. Pero Argentina acaba de perder, no tengo fuerzas para argumentar ni por qué CONICET debería mantenerme la beca.',
#   0.9589058180399495]}

# %% [markdown]
# # LDA

# %%
pp_object = Preprocess()

model = LDA_Model(df, pp_object=pp_object)
model.train(n_components = 5)

model.predict_old(748)
model.predict_new('No tengo ni idea')
# Out:
# Comparing:
# ['Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.']
#
# ----
# 0.
# Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.
# Score: 1.0000000000000002
# ----
# 1.
# No adhiero a una ideología, pero mi tendencia política es hacia la izquierda.
# Score: 0.9999990206168816
# ----
# 2.
# No tengo ni puta idea que es un termino politico economico
# Score: 0.9999976555589556
# ----
# 3.
# Peronista, por qué estoy a favor de la defensa del vulnerable y los intereses nacionales.
# Score: 0.9999967527848094
# ----
# 4.
# No puedo definirme ideológicamente en estos términos porque desconozco a qué hace referencia
# Score: 0.9999943556438323
# ----
# 5.
# La diferencia de horarios (baches eternos) y las pocas pausas para almorzar.
# Score: 0.9999872694979369
# ----
# 6.
# mas opciones de comida vegetarias tanto en bandeja como en el kiosco
# Score: 0.9999864680242746
# ----
# 7.
# De ninguno porque fui a otro planeta y vi otros modos de organización social.
# Score: 0.9999846201418762
# ----
# 8.
# Me interesaría conocer qué piensa el resto de la comunidad de mis aportes en este tema.
# Score: 0.9999656752994392
# ----
# 9.
# El transporte no puede tener un impacto significativo en el salario de los trabajadores que lo utilizan.
# Score: 0.9999540031725364
# Comparing:
# No tengo ni idea
#
# ----
# 0.
# Centro - liberal
# Score: 0.9998103266592872
# ----
# 1.
# Centro-derecha.
# Score: 0.9997998061921496
# ----
# 2.
# Hoy nadie
# Score: 0.9997577606294888
# ----
# 3.
# Pienso que es una joda
# Score: 0.9989467254740878
# ----
# 4.
# Más cursos de diseño
# Score: 0.9986873255357646
# ----
# 5.
# Poca variedad de clases de consultas
# Score: 0.9984729876681194
# ----
# 6.
# Excursiones
# Score: 0.9984116885601519
# ----
# 7.
# excursiones
# Score: 0.9984116885601519
# ----
# 8.
# gallperin
# Score: 0.9984076948065378
# ----
# 9.
# nan
# Score: 0.9984076948065351
# {582: ['Centro - liberal', 0.9998103266592872],
#  503: ['Centro-derecha.', 0.9997998061921496],
#  307: ['Hoy nadie', 0.9997577606294888],
#  299: ['Pienso que es una joda', 0.9989467254740878],
#  386: ['Más cursos de diseño ', 0.9986873255357646],
#  497: ['Poca variedad de clases de consultas', 0.9984729876681194],
#  382: ['Excursiones', 0.9984116885601519],
#  385: ['excursiones ', 0.9984116885601519],
#  424: ['gallperin', 0.9984076948065378],
#  677: ['nan', 0.9984076948065351]}

# %% [markdown]
# # Spacy

# %%
# %%capture
# !python -m spacy download es_core_news_lg

# %%
pp_object = Preprocess(lemma=False, stopwords=False)
model = Spacy_Model(df, pp_object)

# %%
start = time.time()
model.predict_old(748)
end = time.time()

print(f'\nThis took {end - start} seconds.')
# Out:
# Predicting with slow model.
# C:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Semantic_Similarity\..\MyModule\NLPFunctions.py:933: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   best_simil[original_phrase] = preprocessed_phrase_nlp.similarity(doc_nlp)
# Comparing:
# Un poco más con los de izquierda. No me gustan los partidos de derecha.
#
# ----
# 0.
# El Estado regule, equitativo
# Score: 1.0
# ----
# 1.
# Creo que en el estado debe garantizar el derecho al trabajo de todos
# Score: 0.8736255654804946
# ----
# 2.
# El Estado es el principal responsable de que haya pobres
# Score: 0.8414820896740933
# ----
# 3.
# El estado debería auditar el correcto funcionamiento y administración de las empresas de transporte y evaluar si aplica el subsidio.
# Score: 0.8164860955738754
# ----
# 4.
# De izquierda, acuerdo con el objetivo de justicia social, y un estado presente que lo respalde.
# Score: 0.7886102696097327
# ----
# 5.
# Con los de derecha. Por que promueven el empleo y la propiedad privada, el reconocimiento al esfuerzo y reconocen el mérito.
# Score: 0.7798917599461147
# ----
# 6.
# Partidos de derecha. Creo q el camino para salir adelante es el trabajo, el esfuerzo y educación.
# Score: 0.7786162554077319
# ----
# 7.
# El transporte no puede tener un impacto significativo en el salario de los trabajadores que lo utilizan.
# Score: 0.7776068440373713
# ----
# 8.
# El transporte es un derecho, porque es un medio que garantiza el desarrollo, se tiene que subsidiar persiguiendo un fin último de facilitar el acceso al trabajo, eso no tienen nada que ver con generar empresarios de transporte ricos.
# Score: 0.7739384194872798
# ----
# 9.
# Con el centro. Tiene que existir un equilibrio entre conciencia social y economía.
# Score: 0.7727755017620548

# %%
model.train()
# Out:
# Training 0%
# C:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Semantic_Similarity\..\MyModule\NLPFunctions.py:827: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   sim = doc1.similarity(doc2)
# Training 12%
#
# Training 24%
#
# Training 35%
#
# Training 47%
#
# Training 59%
#
# Training 71%
#
# Training 83%
#
# Training 94%
#           749       748       747       746       745       744       743  \
# 749  1.000000  0.134442  0.032323  0.168446  0.164224  0.192764  0.062217
# 748  0.134442  1.000000  0.446511  0.797926  0.725021  0.619897  0.718856
# 747  0.032323  0.446511  1.000000  0.655495  0.717966  0.754676  0.750081
# 746  0.168446  0.797926  0.655495  1.000000  0.796703  0.761577  0.723179
# 745  0.164224  0.725021  0.717966  0.796703  1.000000  0.892640  0.706543
# ..        ...       ...       ...       ...       ...       ...       ...
# 165  0.080861  0.521626  0.655046  0.586476  0.631193  0.648644  0.847917
# 164  0.127131  0.764677  0.605867  0.711582  0.841029  0.767380  0.717121
# 163  0.114721  0.867983  0.500157  0.744316  0.755842  0.628036  0.746453
# 162  0.008245  0.137981  0.606932  0.218473  0.428661  0.495765  0.512678
# 161  0.102456  0.627806  0.715152  0.750149  0.732531  0.698512  0.842176
#
#           742       741       740  ...       171       170       168  \
# 749  0.102351  0.056476  0.167475  ...  0.159497  0.152841  0.100096
# 748  0.527713  0.446086  0.769481  ...  0.751673  0.615677  0.529550
# 747  0.721174  0.803421  0.686983  ...  0.692530  0.770429  0.783012
# 746  0.643076  0.580339  0.822106  ...  0.784047  0.753764  0.674229
# 745  0.840630  0.765176  0.916840  ...  0.910956  0.843744  0.845586
# ..        ...       ...       ...  ...       ...       ...       ...
# 165  0.593915  0.679547  0.562964  ...  0.628083  0.749816  0.635210
# 164  0.741075  0.720752  0.824032  ...  0.870761  0.794915  0.702140
# 163  0.575793  0.481298  0.810989  ...  0.810744  0.718053  0.539755
# 162  0.494466  0.557688  0.352334  ...  0.336687  0.392331  0.601749
# 161  0.643291  0.655853  0.745681  ...  0.783774  0.843272  0.639765
#
#           167       166       165       164       163       162       161
# 749  0.120426  0.118401  0.080861  0.127131  0.114721  0.008245  0.102456
# 748  0.661824  0.462876  0.521626  0.764677  0.867983  0.137981  0.627806
# 747  0.820616  0.517797  0.655046  0.605867  0.500157  0.606932  0.715152
# 746  0.730640  0.536548  0.586476  0.711582  0.744316  0.218473  0.750149
# 745  0.904012  0.636838  0.631193  0.841029  0.755842  0.428661  0.732531
# ..        ...       ...       ...       ...       ...       ...       ...
# 165  0.783584  0.328546  1.000000  0.660320  0.570674  0.544341  0.798208
# 164  0.823266  0.469578  0.660320  1.000000  0.795433  0.293031  0.725031
# 163  0.679745  0.507388  0.570674  0.795433  1.000000  0.165075  0.740824
# 162  0.556626  0.440149  0.544341  0.293031  0.165075  1.000000  0.404086
# 161  0.769675  0.452062  0.798208  0.725031  0.740824  0.404086  1.000000
#
# [505 rows x 505 columns]

# %%
start = time.time()
model.predict_old(748)
end = time.time()

print(f'\nThis took {end - start} seconds.')
# Out:
# Predicting with fast model.
# Comparing:
# ['El Estado regule, equitativo']
#
# ----
# 0.
# El transporte no puede tener un impacto significativo en el salario de los trabajadores que lo utilizan.
# Score: 0.8736255654804946
# ----
# 1.
# El transporte es un derecho, porque es un medio que garantiza el desarrollo, se tiene que subsidiar persiguiendo un fin último de facilitar el acceso al trabajo, eso no tienen nada que ver con generar empresarios de transporte ricos.
# Score: 0.8414820896740933
# ----
# 2.
# Con los de derecha. Por que promueven el empleo y la propiedad privada, el reconocimiento al esfuerzo y reconocen el mérito.
# Score: 0.8164860955738754
# ----
# 3.
# Partidos de derecha. Creo q el camino para salir adelante es el trabajo, el esfuerzo y educación.
# Score: 0.7886102696097327
# ----
# 4.
# De izquierda, acuerdo con el objetivo de justicia social, y un estado presente que lo respalde.
# Score: 0.7798917599461147
# ----
# 5.
# El estado debería auditar el correcto funcionamiento y administración de las empresas de transporte y evaluar si aplica el subsidio.
# Score: 0.7786162554077319
# ----
# 6.
# Estatista Intervencionista Socialista ¿Cómo lo Haría? expropiando latifundios y propiedades en manos extranjeras, interfiriendo  en el margen de ganancia de las empresas, modificando el sistema impositivo, quitando el iva, no pagaría la deuda externa, creando empresas nacionales, legislando el trabajo como un derecho y como una obligación , etc
# Score: 0.7776068440373713
# ----
# 7.
# Creo que en el estado debe garantizar el derecho al trabajo de todos
# Score: 0.7739384194872798
# ----
# 8.
# Con el centro. Tiene que existir un equilibrio entre conciencia social y economía.
# Score: 0.7727755017620548
# ----
# 9.
# El Estado es el principal responsable de que haya pobres
# Score: 0.766150471457
#
# This took 0.0020020008087158203 seconds.
# C:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Semantic_Similarity\..\MyModule\NLPFunctions.py:875: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   index_and_scores = self.df_simil[ID].nlargest(N+1)[1:]

# %%
new_doc = 'No admiro a nadie'
model.predict_new(new_doc)
# Out:
# C:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Semantic_Similarity\..\MyModule\NLPFunctions.py:992: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   best_simil[original_phrase] = new_document_nlp.similarity(doc_nlp)
# Comparing:
# No admiro a nadie
#
# ----
# 0.
# A veces si, a veces no.
# Score: 0.7665018747415421
# ----
# 1.
# Ni idea. Quiero que todxs vivamos bien y que nadie joda a nadie.
# Score: 0.7523564358662747
# ----
# 2.
# No tengo a alguna persona para mencionar
# Score: 0.7387942739827748
# ----
# 3.
# Encuestas intermedias de las materias. No me interesa llenar una encuesta a final de curso si no me va a ayudar a mí.
# Score: 0.6925190111973041
# ----
# 4.
# No sabe, no responde.
# Score: 0.6916405158811242
# ----
# 5.
# No coincido.
# Score: 0.6675259825595191
# ----
# 6.
# No coincido. Los subsidios deben ser dirigidos a quien lo necesita
# Score: 0.6468035998241979
# ----
# 7.
# No tengo
# Score: 0.6429702410628558
# ----
# 8.
# No tengo.
# Score: 0.6429702410628558
# ----
# 9.
# No tengo admiración por nadie, pero lo que hace Santi Maratea me parece bueno.
# Score: 0.6337127468417648
# {749: ['A veces si, a veces no. ', 0.7665018747415421],
#  748: ['Ni idea. Quiero que todxs vivamos bien y que nadie joda a nadie. ',
#   0.7523564358662747],
#  747: ['No tengo a alguna persona para mencionar ', 0.7387942739827748],
#  746: ['Encuestas intermedias de las materias. No me interesa llenar una encuesta a final de curso si no me va a ayudar a mí.',
#   0.6925190111973041],
#  745: ['No sabe, no responde. ', 0.6916405158811242],
#  744: ['No coincido.', 0.6675259825595191],
#  743: ['No coincido. Los subsidios deben ser dirigidos a quien lo necesita ',
#   0.6468035998241979],
#  742: ['No tengo', 0.6429702410628558],
#  741: ['No tengo.', 0.6429702410628558],
#  740: ['No tengo admiración por nadie, pero lo que hace Santi Maratea me parece bueno. ',
#   0.6337127468417648]}
