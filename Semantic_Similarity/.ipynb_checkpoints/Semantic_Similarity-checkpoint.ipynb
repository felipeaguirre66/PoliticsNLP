# %%
import pandas as pd
import regex as re
import unidecode
import nltk
import spacy

path_to_MyModule = '..'

import sys
sys.path.insert(0, path_to_MyModule) 

from MyModule.NLPFunctions import *

# %%
df = pd.read_excel('datos.xlsx')[['ID','texto','desafio']]

# %%
# Limpieza
df.drop_duplicates(subset='texto', inplace=True)

# Quitando texto de mas en columna "desafio"
df['desafio'] = df['desafio'].apply(lambda x: re.findall('[0-9]+', x)[0])

# A str
df['texto'] = df['texto'].astype(str)

# %% [markdown]
# # Preprocess and tokenization

# %%
pp = Preprocess(lemma=False)
df['prepro_text'] = pp.preprocess(df['texto'])

# %% [markdown]
# # TF-IDF

# %%
pp = Preprocess()

model = TF_IDF_Model(df, pp)
matrix = model.train('texto')

model.predict_old('Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.')
model.predict_new('apoyar a messi')
# Out:
# Comparing:
# ['Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.']
#
# ----
# 0.
# Me siento mas identificado con los partidos de derecha. Mi principal motivo es que en mi país, Argentina, los partidos de izquierda están asociados a mucha corrupción.
# Score: 0.20671499192408185
# ----
# 1.
# Me siento más identificado con los partidos de izquierda porque son los que luchan contra la desigualdad y no la ven como algo natural, como sí lo hace la derecha
# Score: 0.1954222776582949
# ----
# 2.
# De izquierda, la derecha nunca estuvo a favor del trabajador.
# Score: 0.16898461589362312
# ----
# 3.
# Derecha. Si bien, me gusta la ideología de la izquierda, no ví que funcionará y por eso elijo derecha
# Score: 0.16084113100018416
# ----
# 4.
# Ideología Centro Derecha
# Score: 0.15014772988749522
# ----
# 5.
# Derecha. No soy partidario de ningún político pero si tengo que decir que se acerca más a mi ideología diría que la derecha es más acertada
# Score: 0.13338762063264303
# ----
# 6.
# De izquierda
# Score: 0.12320172455331864
# ----
# 7.
# Centro-derecha.
# Score: 0.12317755735874264
# ----
# 8.
# Socialmente, de centro-izquierda. Economicamente, de centro-derecha.
# Score: 0.11746274959392884
# ----
# 9.
# Un poco más con los de izquierda. No me gustan los partidos de derecha.
# Score: 0.11340677772649854
# Comparing:
# apoyar a messi
#
# ----
# 0.
# Messi
# Score: 0.6899105804031194
# ----
# 1.
# Messi, actualmente no hay ningún otro referente que valga la pena apoyar/reconocer, uno mas inútil que el otro
# Score: 0.4867776780274469
# ----
# 2.
# Messi, es un ejemplo de esfuerzo y superación, una figura a seguir y un ídolo. Una persona que triunfó haciendo lo que más le gusta.
# Score: 0.2207832573766238
# ----
# 3.
# No logro identificarme totalmente con ningún partido político, lo cual hace que no participe activamente de política más que cuando hay que votar. Siento que simpatizo más con ideas políticas de centro-izquierda, que ponen el foco en la población más vulnerable y pretenden apoyarla en sus reclamos, pero también soy consciente de que los partidos políticos de izquierda en Argentina presentan propuestas irreales y no tienen un gran peso político. Para definirme ideológicamente, me es más fácil expresar las ideas con las que no estoy de acuerdo, que serían políticas libertarias.
# Score: 0.11418333488400331
# ----
# 4.
# Ser humano surfeando en delirios cósmicos
# Score: 0.0
# ----
# 5.
# Desconozco la situación en detalle como para tirar fruta
# Score: 0.0
# ----
# 6.
# No se que comentar acá.
# Score: 0.0
# ----
# 7.
# Favaloro. Logró algo que no se había realizado nunca y murió ahogado por las deudas y un gobierno al que sólo le importaba cobrar sus deudas.
# Score: 0.0
# ----
# 8.
# Horarios más estructurados, que sean o en la mañana o en la tarde, que estén juntos, y que estén distribuidos de forma uniforme a lo largo de la semana.
# Score: 0.0
# ----
# 9.
# Clase media, trabajador. Porque vivo trabajando para mantenerme a mi y a mi familia.
# Score: 0.0
# C:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Semantic_Similarity\..\MyModule\NLPFunctions.py:366: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ID not in self.df['ID'].values:
# C:\Users\Felipe\Desktop\Proyectos\NLP_Politica\Semantic_Similarity\..\MyModule\NLPFunctions.py:371: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   index_and_scores = self.df_similarity[ID].nlargest(N+1)[1:]
# {628: ['Messi', 0.6899105804031194],
#  610: ['Messi, actualmente no hay ningún otro referente que valga la pena apoyar/reconocer, uno mas inútil que el otro',
#   0.4867776780274469],
#  608: ['Messi, es un ejemplo de esfuerzo y superación, una figura a seguir y un ídolo. Una persona que triunfó haciendo lo que más le gusta.',
#   0.2207832573766238],
#  606: ['No logro identificarme totalmente con ningún partido político, lo cual hace que no participe activamente de política más que cuando hay que votar. Siento que simpatizo más con ideas políticas de centro-izquierda, que ponen el foco en la población más vulnerable y pretenden apoyarla en sus reclamos, pero también soy consciente de que los partidos políticos de izquierda en Argentina presentan propuestas irreales y no tienen un gran peso político. Para definirme ideológicamente, me es más fácil expresar las ideas con las que no estoy de acuerdo, que serían políticas libertarias.',
#   0.11418333488400331],
#  573: ['Ser humano surfeando en delirios cósmicos ', 0.0],
#  572: ['Desconozco la situación en detalle como para tirar fruta', 0.0],
#  571: ['No se que comentar acá. ', 0.0],
#  570: ['Favaloro. Logró algo que no se había realizado nunca y murió ahogado por las deudas y un gobierno al que sólo le importaba cobrar sus deudas.',
#   0.0],
#  560: ['Horarios más estructurados, que sean o en la mañana o en la tarde, que estén juntos, y que estén distribuidos de forma uniforme a lo largo de la semana. ',
#   0.0],
#  568: ['Clase media, trabajador. Porque vivo trabajando para mantenerme a mi y a mi familia.',
#   0.0]}

# %% [markdown]
# # LSA

# %%
pp_object = Preprocess()
model = LSA_Model(df, pp_object=pp_object)
model.train()
model.predict_old(748)
model.predict_new('No tengo ni puta idea que es un termino politico')
# Out:
# Comparing:
# ['Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.']
#
# ----
# 0.
# Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.
# Score: 1.0
# ----
# 1.
# Izquierda.Especialmente, sensibilidad social, igualdad, lucha por los derechos.
# Score: 0.9987495164473248
# ----
# 2.
# Me considero una persona de izquierda porque apoyo sus políticas
# Score: 0.9986728280103643
# ----
# 3.
# Con partidos de derecha, porque soy mas afin de las ideas libertarias.
# Score: 0.9936102091295287
# ----
# 4.
# Con las ideas que surgen de partidos de izquierda en tanto promueven el desarrollo del estado orientado a llevar adelante políticas sociales y económicas con objetivos y nociones de equidad y justicia social.
# Score: 0.9933638781872902
# ----
# 5.
# Depende la dirigencia, hoy me identifico con partidos de izquierda, cuando gobierna mucho la derecha me gusta cambiar para equilibrar, y ya es hora
# Score: 0.9927148542501055
# ----
# 6.
# De izquierda. Porque me preocupa la calidad de vida de toda la población
# Score: 0.992233975547882
# ----
# 7.
# Partidos de derecha. Creo que históricamente los partidos considerados de izquierda no han cumplido con los ideales que supuestamente defienden. Sin embargo los de derecha se relacionan más con mi historia familiar y la defensa de esos derechos y el tipo de sociedad en la que deseo vivir.
# Score: 0.9894520663999999
# ----
# 8.
# De izquierda. Los motivos son programáticos, las ideas que defienden y el horizonte de sociedad al que aspiran.
# Score: 0.9878431220113791
# ----
# 9.
# Más identificado con izquierda. Lo tengo asociado a ampliar derechos a las minorías y a acciones tendientes a mejorar la realidad de los sectores más desfavorecidos.
# Score: 0.9876844916083787
# Comparing:
# No tengo ni puta idea que es un termino politico
#
# ----
# 0.
# No tengo ni puta idea que es un termino politico economico
# Score: 0.9998255654612446
# ----
# 1.
# Concuerdo totalmente
# Score: 0.9775999114503304
# ----
# 2.
# Creo que las narrativas en términos politicos y económicos actuales no están a la altura del mundo actual. Son ideologías viejas surgidas en contextos totalmente diferentes, no responden a las necesidades del mundo actual, sus problemáticas y sus avances. Estamos viviendo el inicio de la cuarta revolución industrial y tenemos herramientas sociales de la era de los motores a vapor. Pero respondiendo a la consigna; creo que en términos económicos me siento mas identificado con el libre flujo de capitales y con control activo de un BUEN estado.
# Score: 0.9744565974981635
# ----
# 3.
# Que por momentos, en algunas áreas pidan encarar proyectos y no se de ningún tipo de acompañamiento y sea puro improvisación del alumno con lo que tenga a su alcance para presentar algo.
# Score: 0.9719365566099113
# ----
# 4.
# Cristina Fernández de Kirchner. Principal referente política del país.
# Score: 0.9716759406182061
# ----
# 5.
# Me definiría como liberal. El estado no tiene por que intervenir en el mercado, por lo que hemos vivido hasta ahora en este país, queda demostrado.
# Score: 0.9699730090219304
# ----
# 6.
# Si hubiera que polarizar, diría izquierda. Pero Argentina acaba de perder, no tengo fuerzas para argumentar ni por qué CONICET debería mantenerme la beca.
# Score: 0.9631730652916889
# ----
# 7.
# Nada nuevo
# Score: 0.9564509845856791
# ----
# 8.
# Mi opinión es de mucho desncanto, al ver lo que los partidos políticos le hacen al país. Sólo les interesa llegar al poder y mantenerse ahí.
# Score: 0.9547285914735135
# ----
# 9.
# No tengo admiración por nadie, pero lo que hace Santi Maratea me parece bueno.
# Score: 0.9543277159410414
# {300: ['No tengo ni puta idea que es un termino politico economico',
#   0.9998255654612446],
#  654: ['Concuerdo totalmente', 0.9775999114503304],
#  736: ['Creo que las narrativas en términos politicos y económicos actuales no están a la altura del mundo actual. Son ideologías viejas surgidas en contextos totalmente diferentes, no responden a las necesidades del mundo actual, sus problemáticas y sus avances. Estamos viviendo el inicio de la cuarta revolución industrial y tenemos herramientas sociales de la era de los motores a vapor. Pero respondiendo a la consigna; creo que en términos económicos me siento mas identificado con el libre flujo de capitales y con control activo de un BUEN estado. ',
#   0.9744565974981635],
#  483: ['Que por momentos, en algunas áreas pidan encarar proyectos y no se de ningún tipo de acompañamiento y sea puro improvisación del alumno con lo que tenga a su alcance para presentar algo. ',
#   0.9719365566099113],
#  715: ['Cristina Fernández de Kirchner. Principal referente política del país.',
#   0.9716759406182061],
#  663: ['Me definiría como liberal. El estado no tiene por que intervenir en el mercado, por lo que hemos vivido hasta ahora en este país, queda demostrado.',
#   0.9699730090219304],
#  595: ['Si hubiera que polarizar, diría izquierda. Pero Argentina acaba de perder, no tengo fuerzas para argumentar ni por qué CONICET debería mantenerme la beca.',
#   0.9631730652916889],
#  409: ['Nada nuevo', 0.9564509845856791],
#  163: ['Mi opinión es de mucho desncanto, al ver lo que los partidos políticos le hacen al país. Sólo les interesa llegar al poder y mantenerse ahí.',
#   0.9547285914735135],
#  644: ['No tengo admiración por nadie, pero lo que hace Santi Maratea me parece bueno. ',
#   0.9543277159410414]}

# %% [markdown]
# # LDA

# %%
pp_object = Preprocess()
model = LDA_Model(df, pp_object=pp_object)
model.train()

model.predict_old(748)
model.predict_new('No tengo ni idea')
# Out:
# Comparing:
# ['Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.']
#
# ----
# 0.
# Izquierda en lo que respecta a mi desprecio al capitalismo.Derecha porque soy antidelincuencia.
# Score: 1.0
# ----
# 1.
# No tengo ni puta idea que es un termino politico economico
# Score: 0.9999981469701141
# ----
# 2.
# A ninguna, ninguna figura relativamente conocida me genera esas emociones.
# Score: 0.999992219827546
# ----
# 3.
# Alfonsín, Perón, Evita, Favaloro, Nestor Kirchner
# Score: 0.9999896132933407
# ----
# 4.
# Subsidiar y controlar, son las bases de todo bien funcionamiento.
# Score: 0.9999895005649995
# ----
# 5.
# Me parece correcto habria que controlar más lo que hacen las empresas
# Score: 0.9999883916153474
# ----
# 6.
# las clases en DH tienen mucho potencial pero dejan mucho que desear
# Score: 0.9999863504547108
# ----
# 7.
# Desconozco el trasfondo. La regulación, de todos modos, es relevante.
# Score: 0.999985763433586
# ----
# 8.
# Más experiencias fuera de las clases, en espacios recreativos y lugares interesantes.
# Score: 0.9999836921334224
# ----
# 9.
# Desconozco cómo funciona el subsidio de transporte, por lo que no tengo una opinión formada
# Score: 0.9999772231452535
# Comparing:
# No tengo ni idea
#
# ----
# 0.
# No estoy interesado en la politica
# Score: 0.99997114915567
# ----
# 1.
# Mayormente de acuerdo
# Score: 0.9999706333325478
# ----
# 2.
# Mejores horarios
# Score: 0.9999374909129167
# ----
# 3.
# Hoy nadie
# Score: 0.9999319195179042
# ----
# 4.
# La carga horaria
# Score: 0.9999316358780581
# ----
# 5.
# La carga horario
# Score: 0.9999316358780581
# ----
# 6.
# Tanta carga horaria
# Score: 0.9999316358780581
# ----
# 7.
# NS/NC
# Score: 0.9999008713277675
# ----
# 8.
# Suiza. Neutro.
# Score: 0.9999008713277675
# ----
# 9.
# más horarios de combis.
# Score: 0.9992772305714454
# {609: ['No estoy interesado en la politica', 0.99997114915567],
#  331: ['Mayormente de acuerdo', 0.9999706333325478],
#  505: ['Mejores horarios', 0.9999374909129167],
#  307: ['Hoy nadie', 0.9999319195179042],
#  515: ['La carga horaria', 0.9999316358780581],
#  485: ['La carga horario', 0.9999316358780581],
#  381: ['Tanta carga horaria', 0.9999316358780581],
#  615: ['NS/NC', 0.9999008713277675],
#  614: ['Suiza. Neutro.', 0.9999008713277675],
#  556: ['más horarios de combis.', 0.9992772305714454]}
